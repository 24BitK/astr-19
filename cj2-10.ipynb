# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random

# %%
x = np.random.randint(0,2000,1000)

# %%
plt.hist(x, edgecolor="black", bins=100) 
plt.ylabel("y axis")
plt.xlabel("x axis")
plt.show()
plt.savefig('plot.pdf')
plt.show()
